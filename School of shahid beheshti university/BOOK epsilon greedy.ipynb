# %%
import gym
import numpy as np
import matplotlib.pyplot as plt

# %%
import gym_bandits

# %%
env = gym.make("BanditTenArmedGaussian-v0")

# %%
env.action_space
# Out:
# Discrete(10)

# %%
num_rounds = 20000
count = [[0] for i in range(10)]
sum_rewards = np.zeros(10)
Q = np.zeros(10)

# %%
count[2]
# Out:
# [0]

# %%
def epsilon_greedy(epsilon):
    rand = np.random.random()
    if rand < epsilon:
        action = env.action_space.sample()
    else:
        action = np.argmax(Q)
    return action

# %%
env.step(3)
# Out:
# (0, 0.6778087654816376, True, {})

# %%
for i in range(num_rounds):
    arm = epsilon_greedy(0.1)
    observation, reward, done, info = env.step(arm)
    count[arm].append(count[arm][-1]+reward) 
    sum_rewards[arm] += reward
    #Q[arm] = sum_rewards[arm]/count[arm]

# %%
for i in range(1,10):
    plt.plot(count[i],label = 'the choice of the {}th arm'.format(i))

# %%
Q
# Out:
# array([ 1.3965949 , -0.54412109, -0.1950831 ,  0.56205634, -0.69275707,
#        -1.89649785, -0.21563146,  0.45613645, -1.46833776,  1.76562991])

# %%
np.argmax(Q)
# Out:
# 9
